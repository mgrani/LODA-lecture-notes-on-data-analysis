# %% [markdown]
# # Exercises - Natural Language Processing with NLTK
#
# by
#
# [__Michael Granitzer__ (michael.granitzer@uni-passau.de)]( http://www.mendeley.com/profiles/michael-granitzer/)
#
# <p>
# <p>
# <br>
# __Licences__
# <br />This work is licensed under a <a rel="license" href="http://creativecommons.org/licenses/by-nc-sa/4.0/">Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International License</a>.
# <a rel="license" href="http://creativecommons.org/licenses/by-nc-sa/4.0/" align="left"><img alt="Creative Commons License" style="border-width:0" src="https://i.creativecommons.org/l/by-nc-sa/4.0/88x31.png" /></a>

# %% [markdown]
# # Exercise A: Preprocessing the Reuters 21578 Text Corpus

# %% [markdown]
# ## Task

# %% [markdown]
# The Reuters-21578 is a new corpora that has been extensively used in text mining. In this exercise, you should
#
# 1. download the corpora from http://kdd.ics.uci.edu/databases/reuters21578/reuters21578.html
# 2. Preprocess the titel (`TITLE` Element) and the text (`TEXT` Element) of every document
# 3. Calculate  the 10 most frequent words in the title and 10 most frequent word in the text. In how many documents to this 10 frequent words occur?
# 4. Perform a part of speech tagging on the `TITLE` and `TEXT` alement. What are the 10 most frequent Nouns and Verbs in Title and Text?
# 5. Extract persons and locations from the Reuters documents using the available nltk tagger and compare their frequency distribution and their condidtional frequency distribution. Are there some dependencies and can you explain them?
# 6. Try to find some noun and verb phrases and list them according to their frequency.

# %% [markdown]
# ## Solution

# %%
#list files
import nltk
import os
from os.path import isfile, join
path = "/Users/mgrani/Downloads/reuters21578/"
files = [ join(path,f) for f in os.listdir(path) if f.endswith(".sgm") ]
print files
# Out:
# ['/Users/mgrani/Downloads/reuters21578/reut2-000.sgm', '/Users/mgrani/Downloads/reuters21578/reut2-001.sgm', '/Users/mgrani/Downloads/reuters21578/reut2-002.sgm', '/Users/mgrani/Downloads/reuters21578/reut2-003.sgm', '/Users/mgrani/Downloads/reuters21578/reut2-004.sgm', '/Users/mgrani/Downloads/reuters21578/reut2-005.sgm', '/Users/mgrani/Downloads/reuters21578/reut2-006.sgm', '/Users/mgrani/Downloads/reuters21578/reut2-007.sgm', '/Users/mgrani/Downloads/reuters21578/reut2-008.sgm', '/Users/mgrani/Downloads/reuters21578/reut2-009.sgm', '/Users/mgrani/Downloads/reuters21578/reut2-010.sgm', '/Users/mgrani/Downloads/reuters21578/reut2-011.sgm', '/Users/mgrani/Downloads/reuters21578/reut2-012.sgm', '/Users/mgrani/Downloads/reuters21578/reut2-013.sgm', '/Users/mgrani/Downloads/reuters21578/reut2-014.sgm', '/Users/mgrani/Downloads/reuters21578/reut2-015.sgm', '/Users/mgrani/Downloads/reuters21578/reut2-016.sgm', '/Users/mgrani/Downloads/reuters21578/reut2-017.sgm', '/Users/mgrani/Downloads/reuters21578/reut2-018.sgm', '/Users/mgrani/Downloads/reuters21578/reut2-019.sgm', '/Users/mgrani/Downloads/reuters21578/reut2-020.sgm', '/Users/mgrani/Downloads/reuters21578/reut2-021.sgm']

# %%
#get title/text pairs
import re
def get_documents(files, tags):
  for f in files:
        s = open (f,"r")  
        try:
            for d in s.read().split("<REUTERS"):
                content = [d]
                for t in tags:
                    b,e = d.find("<"+t+">")+len(t)+2, d.find("</"+t+">")-2
                    if b>=0 and e >=0:
                        content.append(re.sub("<.*>" , "" , d[b:e]))
                    else:
                        content.append("")

                if len(content) > 0:
                    yield content
        finally:#needed for cleanup on a potential error. 
            # note that one stream might rely open until the object is destroyed if the iterator is not advanced
            s.close()

# %%
#rudimentary check of parsing
i = 0
nt = nx = 0
for d in get_documents(files, ["TITLE","TEXT"]):
    if d[1] == "":
        print "Error. Document incomplete. No Title:",  d[0][0:83]
        nt = nt + 1
    if d[0] == "":
        nx = nx + 1
        print "Error. Document incomplete. No Text:",  d[0][0:83]
    
    
    i = i +1
     
print "\n\n"
print i, " documents processed."
print nt, " had no title."
print nx, " had no text."
# Out:
# Error. Document incomplete. No Title: <!DOCTYPE lewis SYSTEM "lewis.dtd">
#
# Error. Document incomplete. No Title:  TOPICS="YES" LEWISSPLIT="TRAIN" CGISPLIT="TRAINING-SET" OLDID="5642" NEWID="99">
# <
# Error. Document incomplete. No Title:  TOPICS="YES" LEWISSPLIT="TRAIN" CGISPLIT="TRAINING-SET" OLDID="5644" NEWID="101">
#
# Error. Document incomplete. No Title:  TOPICS="YES" LEWISSPLIT="TRAIN" CGISPLIT="TRAINING-SET" OLDID="5645" NEWID="102">
#
# Error. Document incomplete. No Title:  TOPICS="YES" LEWISSPLIT="TRAIN" CGISPLIT="TRAINING-SET" OLDID="5646" NEWID="103">
#
# Error. Document incomplete. No Title:  TOPICS="YES" LEWISSPLIT="TRAIN" CGISPLIT="TRAINING-SET" OLDID="5675" NEWID="132">
#
# Error. Document incomplete. No Title:  TOPICS="YES" LEWISSPLIT="TRAIN" CGISPLIT="TRAINING-SET" OLDID="5676" NEWID="133">
#
# Error. Document incomplete. No Title:  TOPICS="YES" LEWISSPLIT="TRAIN" CGISPLIT="TRAINING-SET" OLDID="5759" NEWID="216">
#
# Error. Document incomplete. No Title:  TOPICS="YES" LEWISSPLIT="TRAIN" CGISPLIT="TRAINING-SET" OLDID="12600" NEWID="417">
# Error. Document incomplete. No Title:  TOPICS="NO" LEWISSPLIT="TRAIN" CGISPLIT="TRAINING-SET" OLDID="12794" NEWID="611">
#
# Error. Document incomplete. No Title:  TOPICS="NO" LEWISSPLIT="TRAIN" CGISPLIT="TRAINING-SET" OLDID="12821" NEWID="673">
#
# Error. Document incomplete. No Title:  TOPICS="NO" LEWISSPLIT="TRAIN" CGISPLIT="TRAINING-SET" OLDID="12933" NEWID="760">
#
# Error. Document incomplete. No Title:  TOPICS="YES" LEWISSPLIT="TRAIN" CGISPLIT="TRAINING-SET" OLDID="16254" NEWID="934">
# Error. Document incomplete. No Title:  TOPICS="YES" LEWISSPLIT="TRAIN" CGISPLIT="TRAINING-SET" OLDID="16278" NEWID="958">
# Error. Document incomplete. No Title:  TOPICS="NO" LEWISSPLIT="TRAIN" CGISPLIT="TRAINING-SET" OLDID="16313" NEWID="993">
#
# Error. Document incomplete. No Title:  TOPICS="NO" LEWISSPLIT="TRAIN" CGISPLIT="TRAINING-SET" OLDID="16314" NEWID="994">
#
# Error. Document incomplete. No Title: <!DOCTYPE lewis SYSTEM "lewis.dtd">
#
# Error. Document incomplete. No Title:  TOPICS="YES" LEWISSPLIT="TRAIN" CGISPLIT="TRAINING-SET" OLDID="16463" NEWID="1143"
# Error. Document incomplete. No Title:  TOPICS="NO" LEWISSPLIT="TRAIN" CGISPLIT="TRAINING-SET" OLDID="
OPICS="YES" LEWISSPLIT="TEST" CGISPLIT="TRAINING-SET" OLDID="836" NEWID="16301">
#
# Error. Document incomplete. No Title:  TOPICS="YES" LEWISSPLIT="TEST" CGISPLIT="TRAINING-SET" OLDID="1161" NEWID="16626">
# Error. Document incomplete. No Title:  TOPICS="NO" LEWISSPLIT="TEST" CGISPLIT="TRAINING-SET" OLDID="1356" NEWID="16821">
#
# Error. Document incomplete. No Title:  TOPICS="NO" LEWISSPLIT="TEST" CGISPLIT="TRAINING-SET" OLDID="1357" NEWID="16822">
#
# Error. Document incomplete. No Title: <!DOCTYPE lewis SYSTEM "lewis.dtd">
#
# Error. Document incomplete. No Title:  TOPICS="NO" LEWISSPLIT="NOT-USED" CGISPLIT="PUBLISHED-TESTSET" OLDID="21756" NEWID
# Error. Document incomplete. No Title:  TOPICS="YES" LEWISSPLIT="NOT-USED" CGISPLIT="PUBLISHED-TESTSET" OLDID="21835" NEWI
# Error. Document incomplete. No Title:  TOPICS="NO" LEWISSPLIT="TEST" CGISPLIT="TRAINING-SET" OLDID="5842" NEWID="17504">
#
# Error. Document incomplete. No Title:  TOPICS="YES" LEWISSPLIT="TEST" CGISPLIT="TRAINING-SET" OLDID="5922" NEWID="17584">
# Error. Document incomplete. No Title: <!DOCTYPE lewis SYSTEM "lewis.dtd">
#
# Error. Document incomplete. No Title:  TOPICS="NO" LEWISSPLIT="TEST" CGISPLIT="TRAINING-SET" OLDID="7517" NEWID="18072">
#
# Error. Document incomplete. No Title:  TOPICS="NO" LEWISSPLIT="TEST" CGISPLIT="TRAINING-SET" OLDID="6260" NEWID="18508">
#
# Error. Document incomplete. No Title:  TOPICS="YES" LEWISSPLIT="TEST" CGISPLIT="TRAINING-SET" OLDID="6531" NEWID="18779">
# Error. Document incomplete. No Title: <!DOCTYPE lewis SYSTEM "lewis.dtd">
#
# Error. Document incomplete. No Title:
#   TOPICS="NO" LEWISSPLIT="TEST" CGISPLIT="TRAINING-SET" OLDID="7071" NEWID="19235">
#
# Error. Document incomplete. No Title:  TOPICS="NO" LEWISSPLIT="TEST" CGISPLIT="TRAINING-SET" OLDID="7847" NEWID="19519">
#
# Error. Document incomplete. No Title:  TOPICS="NO" LEWISSPLIT="TEST" CGISPLIT="TRAINING-SET" OLDID="7848" NEWID="19520">
#
# Error. Document incomplete. No Title:  TOPICS="NO" LEWISSPLIT="TEST" CGISPLIT="TRAINING-SET" OLDID="7849" NEWID="19521">
#
# Error. Document incomplete. No Title:  TOPICS="NO" LEWISSPLIT="TEST" CGISPLIT="TRAINING-SET" OLDID="7850" NEWID="19522">
#
# Error. Document incomplete. No Title:  TOPICS="NO" LEWISSPLIT="TEST" CGISPLIT="TRAINING-SET" OLDID="7851" NEWID="19523">
#
# Error. Document incomplete. No Title:  TOPICS="NO" LEWISSPLIT="TEST" CGISPLIT="TRAINING-SET" OLDID="7852" NEWID="19524">
#
# Error. Document incomplete. No Title:  TOPICS="NO" LEWISSPLIT="TEST" CGISPLIT="TRAINING-SET" OLDID="7914" NEWID="19586">
#
# Error. Document incomplete. No Title: <!DOCTYPE lewis SYSTEM "lewis.dtd">
#
# Error. Document incomplete. No Title:  TOPICS="YES" LEWISSPLIT="TEST" CGISPLIT="TRAINING-SET" OLDID="20809" NEWID="20214"
# Error. Document incomplete. No Title:  TOPICS="YES" LEWISSPLIT="TEST" CGISPLIT="TRAINING-SET" OLDID="20843" NEWID="20248"
# Error. Document incomplete. No Title:  TOPICS="YES" LEWISSPLIT="TEST" CGISPLIT="TRAINING-SET" OLDID="20458" NEWID="20979"
# Error. Document incomplete. No Title: <!DOCTYPE lewis SYSTEM "lewis.dtd">
#
# Error. Document incomplete. No Title:  TOPICS="YES" LEWISSPLIT="TEST" CGISPLIT="TRAINING-SET" OLDID="20379" NEWID="21058"
# Error. Document incomplete. No Title:  TOPICS="YES" LEWISSPLIT="TEST" CGISPLIT="TRAINING-SET" OLDID="20355" NEWID="21082"
# Error. Document incomplete. No Title:  TOPICS="YES" LEWISSPLIT="TEST" CGISPLIT="TRAINING-SET" OLDID="20224" NEWID="21212"
#
#
#
# 21600  documents processed.
# 759  had no title.
# 0  had no text.

# %%
import nltk

doc_tokens_title, doc_tokens_text = zip(*[ 
                                           ( nltk.word_tokenize(d[1]), 
                                             nltk.word_tokenize(d[2])
                                           ) for d in get_documents(files, 
                                                                    ["TITLE","TEXT"])
                                         ]
                                        )

# %%
fdtitle = nltk.FreqDist([t  for sent in doc_tokens_title for t in sent]).most_common(30)

# %%
fdtext = nltk.FreqDist([t  for sent in doc_tokens_text for t in sent]).most_common(30)

# %%
for a,b in zip(fdtitle,fdtext):
    print a, "\t\t", b
# Out:
# (';', 9708) 		('the', 119923)
# ('&', 9707) 		(',', 110823)
# ('lt', 9705) 		('.', 104305)
# ('>', 9702) 		('of', 72108)
# ('TO', 3415) 		('to', 68439)
# ('IN', 1997) 		('and', 53347)
# ('QTR', 1940) 		('said', 52880)
# ('NET', 1577) 		('in', 49907)
# ('INC', 1353) 		('a', 48367)
# (',', 1030) 		(';', 44028)
# ('CORP', 1024) 		('&', 43911)
# ('FOR', 986) 		('#', 38138)
# ('U.S.', 928) 		('mln', 25466)
# ('OF', 901) 		('for', 25177)
# ('ON', 849) 		('The', 24225)
# ('UNIT', 825) 		('dlrs', 20256)
# ('MLN', 819) 		('2', 19485)
# ('SAYS', 747) 		('3', 19372)
# ('SETS', 710) 		("'s", 18378)
# ('4TH', 700) 		('it', 18068)
# ('BANK', 685) 		('on', 17783)
# ("'S", 676) 		('pct', 16965)
# ('NEW', 657) 		('is', 16755)
# ('PCT', 558) 		('that', 15189)
# ('SEES', 556) 		('from', 14931)
# ('LOSS', 544) 		('its', 14723)
# ('YEAR', 530) 		('will', 14646)
# ('3RD', 518) 		('by', 14577)
# ('JAPAN', 502) 		('vs', 14564)
# ('AND', 483) 		('be', 14563)
